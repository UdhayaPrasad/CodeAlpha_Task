# %%
import matplotlib.pyplot as plt
from sklearn import datasets as data
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.metrics import accuracy_score

# %%
digits_data = data.load_digits()

# %% [markdown]
# # **Data**

# %%
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(digits_data.images[i],cmap='grey',interpolation='nearest')

# %%
x = digits_data.data
y  = digits_data.target

# %% [markdown]
# # **Training Testing Split**

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %% [markdown]
# # **Data Normalization**

# %%
X_train = X_train/255
X_test = X_test/255

# %%
X_train
# Out:
# array([[0.        , 0.        , 0.03529412, ..., 0.02352941, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.02745098, ..., 0.01176471, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.02352941, 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.01960784, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.01568627, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.00392157, ..., 0.05882353, 0.01960784,
#         0.        ]])

# %%
X_test
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.00784314, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.05490196, 0.00392157,
#         0.        ],
#        [0.        , 0.        , 0.02745098, ..., 0.02745098, 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.01176471, ..., 0.05882353, 0.01960784,
#         0.        ],
#        [0.        , 0.        , 0.00392157, ..., 0.0627451 , 0.03529412,
#         0.00392157],
#        [0.        , 0.        , 0.01176471, ..., 0.04705882, 0.02745098,
#         0.        ]])

# %%
Kmodel = KNeighborsClassifier(n_neighbors=5)
Kmodel.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
kpredict = Kmodel.predict(X_test)

# %%
score = accuracy_score(y_test,kpredict)*100
score
# Out:
# 98.88888888888889

# %%
Rmodel = RandomForestClassifier(n_estimators=100)
Rmodel.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
Rpredict = Rmodel.predict(X_test)

# %%
Rscore = accuracy_score(y_test,Rpredict)*100
Rscore
# Out:
# 96.38888888888889

# %%
Amodel = AdaBoostClassifier(n_estimators=100)
Amodel.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=100)

# %%
Apredict = Amodel.predict(X_test)

# %%
Ascore = accuracy_score(y_test,Apredict)*100
Ascore
# Out:
# 80.27777777777779
